# %%
import pandas as pd
import sqlite3


conn = sqlite3.connect(':memory:') 

with open('BX-Book-Ratings.sql', 'r') as file:
    sql_script = file.read()
    cursor = conn.cursor()
    cursor.executescript(sql_script)


query = "SELECT * FROM BX-Book-Ratings;"  
df = pd.read_sql_query(query, conn)


conn.close()

# %%
import pandas as pd

path = 'BX-'
l_path = ['Book-Ratings',
          'Books',
          'Users'
]

dataframes = {}


def replace_characters(df):
    df.replace('%amp;', '&', regex=True, inplace=True)
    df.replace('EOF', '', regex=True, inplace=True)


for crt in l_path:
    final_path = path + crt + '.csv'
    dataframes[crt] = pd.read_csv(final_path, sep=';', encoding='latin-1', on_bad_lines = 'warn', dtype=object)
    replace_characters(dataframes[crt])


ratings_df = dataframes['Book-Ratings']
books_df = dataframes['Books']
users_df = dataframes['Users']

display(ratings_df)
display(books_df)
display(users_df)
# Out:
# Skipping line 6452: expected 8 fields, saw 9
# Skipping line 43667: expected 8 fields, saw 10
# Skipping line 51751: expected 8 fields, saw 9
#
# Skipping line 92038: expected 8 fields, saw 9
# Skipping line 104319: expected 8 fields, saw 9
# Skipping line 121768: expected 8 fields, saw 9
#
# Skipping line 144058: expected 8 fields, saw 9
# Skipping line 150789: expected 8 fields, saw 9
# Skipping line 157128: expected 8 fields, saw 9
#         User-ID         ISBN Book-Rating
# 0        276725   034545104X           0
# 1        276726   0155061224           5
# 2        276727   0446520802           0
# 3        276729   052165615X           3
# 4        276729   0521795028           6
# ...         ...          ...         ...
# 1149775  276704   1563526298           9
# 1149776  276706   0679447156           0
# 1149777  276709   0515107662          10
# 1149778  276721   0590442449          10
# 1149779  276723  05162443314           8
#
# [1149780 rows x 3 columns]
# ...

# %%
ratings = ratings_df
books = books_df
users = users_df


display(ratings)
display(books)
display(users)
# Out:
#         User-ID         ISBN Book-Rating
# 0        276725   034545104X           0
# 1        276726   0155061224           5
# 2        276727   0446520802           0
# 3        276729   052165615X           3
# 4        276729   0521795028           6
# ...         ...          ...         ...
# 1149775  276704   1563526298           9
# 1149776  276706   0679447156           0
# 1149777  276709   0515107662          10
# 1149778  276721   0590442449          10
# 1149779  276723  05162443314           8
#
# [1149780 rows x 3 columns]
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...

# %% [markdown]
# I want to make 2 merges: ratings with books and ratings with users

# %%
def merge_unique_col(left_df, right_df, left_index, right_index):

  merged_df = left_df.merge(right_df, left_on=left_index, right_on = right_index, suffixes=('', '_remove'))

  merged_df.drop(
              [i for i in merged_df.columns if 'remove' in i],
               axis=1, inplace=True
               )

  return merged_df

ratings_books = merge_unique_col(ratings, books, 'ISBN', 'ISBN')

display(ratings_books)

ratings_users = merge_unique_col(ratings, users, 'User-ID', 'User-ID')

display(ratings_users)
# Out:
#        User-ID        ISBN Book-Rating  \
# 0       276725  034545104X           0
# 1         2313  034545104X           5
# 2         6543  034545104X           0
# 3         8680  034545104X           5
# 4        10314  034545104X           9
# ...        ...         ...         ...
# 893882  276688  0517145553           0
# 893883  276688  1575660792           7
# 893884  276690  0590907301           0
# 893885  276704  0679752714           0
# 893886  276704  0806917695           5
#
#                                                Book-Title      Book-Author  \
# 0                                    Flesh Tones: A Novel       M. J. Rose
# 1                                    Flesh Tones: A Novel       M. J. Rose
# 2                                    Flesh Tones: A Novel       M. J. Rose
# 3                                    Flesh Tones: A Novel       M. J. Rose
# 4                                    Flesh Tones: A Novel       M. J. Rose
# ...

# %% [markdown]
# I want to identify the book with the highest average rating

# %%
ratings_books['Book-Rating'] = ratings_books['Book-Rating'].astype(int)

# %%
average_ratings = ratings_books.groupby('ISBN')['Book-Rating'].mean()

highest_average_rating_isbn = average_ratings.nlargest(4)

print(highest_average_rating_isbn)
# Out:
# ISBN
# 0001360469    10.0
# 0001374869    10.0
# 0001821326    10.0
# 0001845039    10.0
# Name: Book-Rating, dtype: float64

# %%
highest_average_rating_books = ratings_books[ratings_books['ISBN'].isin(highest_average_rating_isbn.index)]

print(highest_average_rating_books['Book-Title'])
# Out:
# 424741                                        Babe Dressing
# 424742         Baby Plays (Collins Baby and Toddler Series)
# 767054                                  The Moon of Gomrath
# 981995    Paddington at the Tower (A Paddington Picture ...
# Name: Book-Title, dtype: object

# %% [markdown]
# Find the books with the highest average rating but who have atleast 100 ratings

# %%
avg_ratings = ratings_books.groupby('ISBN')['Book-Rating'].mean()

rating_counts = ratings_books['ISBN'].value_counts()

filtered_books = average_ratings[rating_counts >= 100]

sorted_books = filtered_books.sort_values(ascending=False)

top_books = sorted_books.head(4)

print(top_books)
# Out:
# ISBN
# 0439064864    6.611765
# 0439139597    6.541237
# 0439136350    6.467005
# 0590353403    6.363095
# Name: Book-Rating, dtype: float64

# %%
top_avg_over_100 = ratings_books[ratings_books['ISBN'].isin(top_books.index)]

print(top_avg_over_100['Book-Title'].unique())
# Out:
# ['Harry Potter and the Chamber of Secrets (Book 2)'
#  'Harry Potter and the Prisoner of Azkaban (Book 3)'
#  'Harry Potter and the Goblet of Fire (Book 4)'
#  "Harry Potter and the Sorcerer's Stone (Book 1)"]

# %% [markdown]
# Then, the books with the most 10 ratings

# %%
ratings_10 = ratings_books[ratings_books['Book-Rating'] == 10]

ratings_10_count = ratings_10.groupby('ISBN').size()

isbn_with_most_10_ratings = ratings_10_count.nlargest(4)

print(isbn_with_most_10_ratings)
# Out:
# ISBN
# 0385504209    158
# 059035342X    152
# 0316666343    148
# 043935806X    111
# dtype: int64

# %%
highest_10_ratings_books = ratings_books[ratings_books['ISBN'].isin(isbn_with_most_10_ratings.index)]

print(highest_10_ratings_books['Book-Title'].unique())
# Out:
# ['Harry Potter and the Order of the Phoenix (Book 5)'
#  'The Lovely Bones: A Novel' 'The Da Vinci Code'
#  "Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))"]

# %% [markdown]
# For the international aspect I want to see the 5 countries which gave the most reviews.
# First of all I need to normaliza the location column

# %%
location_split = ratings_users['Location'].str.split(',', n=2, expand=True)
ratings_users['City'] = location_split[0].str.strip()
ratings_users['State'] = location_split[1].str.strip()
ratings_users['Country'] = location_split[2].str.strip()

ratings_users = ratings_users.drop('Location', axis=1)


display(ratings_users)
# Out:
#         User-ID         ISBN Book-Rating  Age         City            State  \
# 0        276725   034545104X           0  NaN        tyler            texas
# 1        276726   0155061224           5  NaN      seattle       washington
# 2        276727   0446520802           0   16            h  new south wales
# 3        276729   052165615X           3   16       rijeka              n/a
# 4        276729   0521795028           6   16       rijeka              n/a
# ...         ...          ...         ...  ...          ...              ...
# 1149775  276704   1563526298           9  NaN   cedar park            texas
# 1149776  276706   0679447156           0   18       quebec           quebec
# 1149777  276709   0515107662          10   38   mannington    west virginia
# 1149778  276721   0590442449          10   14   providence     rhode island
# 1149779  276723  05162443314           8   12  san antonio            texas
#
#            Country
# 0              usa
# ...

# %%
nan_country_entries = ratings_users[ratings_users['Country'].notna()]

# display(nan_country_entries)

most_reviewed_country = ratings_users['Country'].value_counts().head(5)
print(most_reviewed_country)
# Out:
# usa               447544
# canada             56164
# united kingdom     29858
# germany            24177
# spain              16506
# Name: Country, dtype: int64

# %% [markdown]
# I want to know the authors of the titles who appears the most in the book titles obtained previously

# %%
l_books_avg = list(top_avg_over_100['Book-Title'].unique())

l_books_10 = list(highest_10_ratings_books['Book-Title'].unique())

l_best_books = l_books_avg + l_books_10

l_best_books = list(set(l_best_books))

# print(l_best_books)


best_auth = ratings_books[ratings_books['Book-Title'].isin(l_best_books)]
best_auth = best_auth.drop_duplicates(subset=['Book-Title'])

display(best_auth)


top_authors = best_auth['Book-Author'].value_counts().head(4)

print(top_authors)
# Out:
#        User-ID        ISBN  Book-Rating  \
# 1992    276788  043935806X            7
# 6574    276925  0316666343            0
# 7931    276925  0385504209            8
# 12721   276929  0439064864            0
# 13370   276939  059035342X            0
# 54431   277427  0439136369            0
# 54657   277427  043936213X            0
# 130656  278356  0439139600           10
#
#                                                Book-Title    Book-Author  \
# 1992    Harry Potter and the Order of the Phoenix (Boo...  J. K. Rowling
# 6574                            The Lovely Bones: A Novel   Alice Sebold
# 7931                                    The Da Vinci Code      Dan Brown
# 12721    Harry Potter and the Chamber of Secrets (Book 2)  J. K. Rowling
# 13370   Harry Potter and the Sorcerer's Stone (Harry P...  J. K. Rowling
# 54431   Harry Potter and the Prisoner of Azkaban (Book 3)  J. K. Rowling
# 54657      Harry Potter and the Sorcerer's Stone (Book 1)  J. K. Rowling
# ...

# %% [markdown]
# Using google books API
#
# https://www.googleapis.com/books/v1/volumes?q=search_term&key=AIzaSyCBCKiMTkSW3mjEVooUwMhxKet4_jGTvWk

# %%
import requests


final_books = pd.DataFrame()

l_desc = []

# print(l_best_books)

for title in l_best_books:


  url = 'https://www.googleapis.com/books/v1/volumes?q={}&key=AIzaSyCBCKiMTkSW3mjEVooUwMhxKet4_jGTvWk'.format(title)

  response = requests.get(url)

  if response.status_code == 200:
      book_json = response.json()
      api_books = pd.json_normalize(book_json['items'])

      # api_books = api_books.loc[api_books['volumeInfo.title'].str.lower() == title.lower()]

      api_books = api_books.sort_values(by='volumeInfo.publishedDate', ascending = False)

      api_books = api_books.head(1)


      final_books = pd.concat([final_books, api_books], ignore_index=True)

      
  else:
      print('Error:', response.status_code)

# regex to remove the extra HP book

display(final_books)
# Out:
#            kind            id         etag  \
# 0  books#volume  3YUrtAEACAAJ  TcZoKofSV3I
# 1  books#volume  BvRLzwEACAAJ  U1ZM9dg96KQ
# 2  books#volume  ZiJMzwEACAAJ  n2h1IRO3E7U
# 3  books#volume  DwqFzQEACAAJ  UYtpy0CoJcA
# 4  books#volume  XPlLzwEACAAJ  2YfhvApl6i8
# 5  books#volume  6-pmDwAAQBAJ  EdHJoPwmX4s
# 6  books#volume  StdvEAAAQBAJ  wbVc4a+Su4Q
# 7  books#volume  ZH6pzwEACAAJ  E2ObT1xTXGk
#
#                                             selfLink  \
# 0  https://www.googleapis.com/books/v1/volumes/3Y...
# 1  https://www.googleapis.com/books/v1/volumes/Bv...
# 2  https://www.googleapis.com/books/v1/volumes/Zi...
# 3  https://www.googleapis.com/books/v1/volumes/Dw...
# 4  https://www.googleapis.com/books/v1/volumes/XP...
# 5  https://www.googleapis.com/books/v1/volumes/6-...
# 6  https://www.googleapis.com/books/v1/volumes/St...
# 7  https://www.googleapis.com/books/v1/volumes/ZH...
#
#                                     volumeInfo.title  \
# ...

# %% [markdown]
# I want to obtain a description for the selected books

# %%
google_books = final_books
best_books_local = best_auth

ser_desc = google_books['volumeInfo.description']

display(ser_desc)

best_books_local['description'] = best_books_local['Book-Title'].map(ser_desc)

display(best_books_local)
# Out:
# 0    A special new edition in celebration of the 20...
# 1    Harry wants to get away from the pernicious Du...
# 2    Harry Potter has never been the star of a Quid...
# 3    Susie Salmon is just like any other young girl...
# 4    There is a door at the end of a silent corrido...
# 5    Robert Langdon menerima telepon misterius yang...
# 6    The Unofficial Harry Potter Companion Volume 2...
# 7    The third book in the Harry Potter series, ill...
# Name: volumeInfo.description, dtype: object
#        User-ID        ISBN  Book-Rating  \
# 1992    276788  043935806X            7
# 6574    276925  0316666343            0
# 7931    276925  0385504209            8
# 12721   276929  0439064864            0
# 13370   276939  059035342X            0
# 54431   277427  0439136369            0
# 54657   277427  043936213X            0
# 130656  278356  0439139600           10
#
#                                                Book-Title    Book-Author  \
# ...

# %% [markdown]
# For international success I want to find the best author for the youth

# %%
young_users = users
youth_books = books

young_users = young_users.dropna(subset=['Age'])

young_users['Age'] = young_users['Age'].astype(int)

young_users = young_users[young_users['Age'] < 35]


young_ratings = merge_unique_col(young_users, ratings, 'User-ID', 'User-ID')

display(young_ratings)


young_ratings_books = merge_unique_col(young_ratings, books, 'ISBN', 'ISBN')


author_ratings = young_ratings_books.groupby('Book-Author')['Book-Rating'].mean()


best_author_youth = author_ratings.idxmax()


print(best_author_youth)
# Out:
# <ipython-input-222-a8c8f4af5046>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   young_users['Age'] = young_users['Age'].astype(int)
#        User-ID                         Location  Age        ISBN Book-Rating
# 0            2        stockton, california, usa   18  0195153448           0
# 1           10       albacete, wisconsin, spain   26  1841721522           0
# 2           10       albacete, wisconsin, spain   26  8477024456           6
# 3           19                        weston, ,   14  0375759778           7
# 4           20     langhorne, pennsylvania, usa   19  0425163091           0
# ...        ...                              ...  ...         ...         ...
# ...

# %%
import requests
from bs4 import BeautifulSoup

def get_author_info(author_name):
    
    url = f"https://en.wikipedia.org/w/api.php?action=query&format=json&prop=extracts&exintro=true&redirects=true&titles={author_name}"

    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        pages = data.get("query", {}).get("pages", {})
        page_id = next(iter(pages.keys())) 
        page_info = pages.get(page_id, {})
        extract = page_info.get("extract")

        
        soup = BeautifulSoup(extract, 'html.parser')
        plain_text = soup.get_text(separator="\n")
        return plain_text

l_auth = best_books_local['Book-Author'].to_list()

l_auth = list(set(l_auth))

l_auth.append(best_author_youth)

# print(l_auth)

l_desc = []

for author_name in l_auth:
  author_info = get_author_info(author_name)

  l_desc.append(author_info)


# print(l_desc)


  
auth_desc = {k: v for k, v in zip(l_auth, l_desc)}

auth_desc = pd.DataFrame([auth_desc], index=['Description'])

auth_desc = auth_desc.T

display(auth_desc)
# Out:
#                                                        Description
# J. K. Rowling    \n\n\n\nJoanne Rowling\n  (\n "rolling"; born ...
# Alice Sebold     \n\n\n\n\n\n\n\nAlice Sebold\n (born September...
# Dan Brown        \n\n\n\nDaniel Gerhard Brown\n (born June 22, ...
# Agatha Christie  \n\n\n\nDame Agatha Mary Clarissa Christie, La...
